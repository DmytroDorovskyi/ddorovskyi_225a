# %% [markdown]
# <a href="https://colab.research.google.com/github/DmytroDorovskyi/ddorovskyi_225a/blob/main/bms225a_ds_workshop_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
# install scanpy with additional dependences
# leiden for clustering, harmony for batch correction and skmisc which is needed for HVG selection
# !pip install --quiet 'scanpy[leiden,harmony,skmisc]'

# %% [markdown]
# The following cell downloads the original data and creates the data files `/content/blood_RNA_raw_counts.h5ad` and `/content/blood_RNA_raw_counts_SCG12.h5ad` that we will use for our analysis.

# %%
# @title Download Data and create the **raw data** files that we will use for our analysis
################# THIS IS NOT PART OF THE WORKFLOW ##################
import os

if not os.path.exists('/content/blood_RNA.h5ad'):
  # downloading the data from the paper takes ~1min
  # !wget https://figshare.com/ndownloader/files/38849385?private_link=8aaa376913da23ae0def -O blood_RNA.h5ad > /dev/null 2>&1


if not os.path.exists('/content/blood_RNA_raw_counts.h5ad'):
  # -- create the raw data by removing all processed data information from the author's file
  import scanpy as sc
  # load the single cell RNA seq dataset from the h5ad file
  adata_processed = sc.read_h5ad('blood_RNA.h5ad') # AnnData object
  X_raw_counts = adata_processed.layers['counts']
  # the var dataframe
  raw_var_df = adata_processed.raw.var.copy()
  for i in raw_var_df.columns:
    del raw_var_df[i]
  raw_var_df['gene_name'] = raw_var_df.index
  # the obs dataframe
  raw_obs_df = adata_processed.obs[['LIBRARY',	'CoLabs_patient',	'condition']]
  raw_obs_df.columns = ['LIBRARY_ID', 'patient_id', 'condition']
  # create the anndata object
  adata = sc.AnnData(X = X_raw_counts, var=raw_var_df, obs=raw_obs_df)
  adata.write_h5ad('blood_RNA_raw_counts.h5ad')
  adata=adata[ adata.obs['LIBRARY_ID'] == 'XAUT1-POOL-SCG12']
  adata.write_h5ad('blood_RNA_raw_counts_SCG12.h5ad')
  del adata, adata_processed # delete the all data

# %% [markdown]
# # Single cell RNA seq analysis (single batch)
# ## Let's do a single batch first
# The `'blood_RNA_raw_counts_SCG12.h5ad'` file only contains the single-cell data from a single sequencing batch (library):
#
# LIBRARY_ID: `XAUT1-POOL-SCG12`.

# %%
import pandas as pd
import scanpy as sc

# %%
### Settings ###

# (optional) Show more columns in output
pd.set_option('display.max_columns', 50)

# (optional) Set parameters for the figures // sc.settings.set_figure_params?
sc.settings.set_figure_params(dpi=80,fontsize=16, facecolor="white",figsize=(8,6),color_map='viridis')

# (optional) Suppress all warnings -- not recommended when working on your research projects!
import warnings
warnings.filterwarnings("ignore")

# print out the package versions
print('scanpy version:', sc.__version__)
# Out:
# scanpy version: 1.10.3

# %% [markdown]
# ## STEP 0: Load the data (raw counts)

# %%
###################################################### <- this will mark the functions that will change/update adata
adata = sc.read_h5ad('blood_RNA_raw_counts_SCG12.h5ad') # load the AnnData object from the h5ad file

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6410 × 22741
#     obs: 'LIBRARY_ID', 'patient_id', 'condition'
#     var: 'gene_name'

# %%
# [🔺] lets explore what is in adata
# adata.obs, adata.X, adata.var, adata.var_names

# %%
adata.var_names
# Out:
# Index(['RP11-34P13.7', 'RP11-34P13.15', 'RP11-34P13.16', 'RP11-34P13.13',
#        'FO538757.2', 'FO538757.1', 'AP006222.2', 'RP4-669L17.10',
#        'RP4-669L17.8', 'RP5-857K21.4',
#        ...
#        'AJ006998.2', 'UBE3AP2', 'AP000569.9', 'AP000320.6', 'AP001619.2',
#        'RSPH1', 'IMMTP1', 'LINC00315', 'AL133493.2', 'FTCD'],
#       dtype='object', length=22741)

# %% [markdown]
# ## STEP 1: Quality control

# %%
######################################################
# mitochondrial genes, "MT-" for human, "Mt-" for mouse
adata.var["mt"] = adata.var_names.str.startswith("MT-")

# %%
adata.var.head()
# Out:
#                    gene_name     mt
# RP11-34P13.7    RP11-34P13.7  False
# RP11-34P13.15  RP11-34P13.15  False
# RP11-34P13.16  RP11-34P13.16  False
# RP11-34P13.13  RP11-34P13.13  False
# FO538757.2        FO538757.2  False

# %%
# [🔺] pandas practice: select the var rows that correspond to mitochondrial genes
# Hint: slice adata.var where the 'mt' column of adata.var is equal to True

# %%
adata.var[adata.var['mt']==True]
# Out:
#         gene_name    mt
# MT-RNR1   MT-RNR1  True
# MT-TV       MT-TV  True
# MT-RNR2   MT-RNR2  True
# MT-TL1     MT-TL1  True
# MT-ND1     MT-ND1  True
# MT-TM       MT-TM  True
# MT-ND2     MT-ND2  True
# MT-TA       MT-TA  True
# MT-TC       MT-TC  True
# MT-CO1     MT-CO1  True
# MT-CO2     MT-CO2  True
# MT-TK       MT-TK  True
# MT-ATP8   MT-ATP8  True
# MT-ATP6   MT-ATP6  True
# MT-CO3     MT-CO3  True
# MT-ND3     MT-ND3  True
# MT-ND4L   MT-ND4L  True
# MT-ND4     MT-ND4  True
# MT-ND5     MT-ND5  True
# MT-ND6     MT-ND6  True
# MT-CYB     MT-CYB  True
# MT-TP       MT-TP  True
# MT-TQ       MT-TQ  True
# MT-TY       MT-TY  True
# MT-TD       MT-TD  True
# MT-TH       MT-TH  True
# MT-TL2     MT-TL2  True
# MT-TE       MT-TE  True

# %%
# [🔹] for practice you can also add a column that indicates whether a gene is ribosomal
# ribosomal genes start with "RP" for human, "Rp" for mouse

# %% [markdown]
# ### Calculate QC metrics

# %%
adata # lets remind ourseleves about adata, the following command will add a lot of information
# Out:
# AnnData object with n_obs × n_vars = 6410 × 22741
#     obs: 'LIBRARY_ID', 'patient_id', 'condition'
#     var: 'gene_name', 'mt'

# %%
######################################################
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True, log1p=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6410 × 22741
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %% [markdown]
# ### Filter genes

# %%
######################################################
sc.pp.filter_genes(adata,min_cells=5) #filter genes that are expressed in fewer than 5 cells

# %%
adata # notice that the number of genes decreased
# Out:
# AnnData object with n_obs × n_vars = 6410 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %% [markdown]
# ### Visualize QC metrics (cells)

# %%
sc.pl.violin(
    adata,
    keys = ["log1p_n_genes_by_counts", "log1p_total_counts", "pct_counts_mt"],
    jitter=0.1,
    multi_panel=True,
    size=1
)

# %%
sc.pl.scatter(adata, "log1p_total_counts", "pct_counts_mt", color="log1p_n_genes_by_counts",size=50)

# %% [markdown]
# ### Filter cells

# %%
# [🔺] pandas practice: How many cells have log1p_total_counts above 8?

# %%
#condition = adata.obs['log1p_total_counts']>8
adata.obs[condition]#
# Out:
#                             LIBRARY_ID  patient_id condition  \
# AAACCTGAGTCAATAG-1_2  XAUT1-POOL-SCG12   XAUT1-HS2        HC
# AAACCTGCATTAACCG-1_2  XAUT1-POOL-SCG12   XAUT1-HS3        HC
# AAACCTGTCAGCACAT-1_2  XAUT1-POOL-SCG12   XAUT1-HS4        HC
# AAACGGGGTCGCCATG-1_2  XAUT1-POOL-SCG12   XAUT1-HS4        HC
# AAACGGGGTTAAAGTG-1_2  XAUT1-POOL-SCG12   XAUT1-HS2        HC
# ...                                ...         ...       ...
# TTTGGTTAGGCGACAT-1_2  XAUT1-POOL-SCG12  XAUT1-HS10       UCV
# TTTGGTTGTCAGAGGT-1_2  XAUT1-POOL-SCG12   XAUT1-HS8      UCNB
# TTTGGTTTCACAGTAC-1_2  XAUT1-POOL-SCG12  XAUT1-HS10       UCV
# TTTGTCACACATCCAA-1_2  XAUT1-POOL-SCG12   XAUT1-HS3        HC
# TTTGTCAGTTGTACAC-1_2  XAUT1-POOL-SCG12   XAUT1-HS3        HC
#
#                       n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCTGAGTCAATAG-1_2               1317                 7.183871
# AAACCTGCATTAACCG-1_2               1244                 7.126891
# AAACCTGTCAGCACAT-1_2               1478                 7.299121
# AAACGGGGTCGCCATG-1_2               1298                 7.169350
# AAACGGGGTTAAAGTG-1_2               1557                 7.351158
# ...                                 ...                      ...
# TTTGGTTAGGCGACAT-1_2               1418                 7.257708
# TTTGGTTGTCAGAGGT-1_2               1703                 7.440734
# TTTGGTTTCACAGTAC-1_2               1941                 7.571474
# TTTGTCACACATCCAA-1_2               1902                 7.551187
# TTTGTCAGTTGTACAC-1_2               1257                 7.137278
#
#                       total_counts  log1p_total_counts  \
# AAACCTGAGTCAATAG-1_2        3584.0            8.184514
# AAACCTGCATTAACCG-1_2        2982.0            8.000685
# AAACCTGTCAGCACAT-1_2        5301.0            8.575839
# AAACGGGGTCGCCATG-1_2        4570.0            8.427487
# AAACGGGGTTAAAGTG-1_2        3972.0            8.287277
# ...                            ...                 ...
# TTTGGTTAGGCGACAT-1_2        3680.0            8.210940
# TTTGGTTGTCAGAGGT-1_2        4932.0            8.503703
# TTTGGTTTCACAGTAC-1_2        4431.0            8.396606
# TTTGTCACACATCCAA-1_2        6315.0            8.750841
# TTTGTCAGTTGTACAC-1_2        3364.0            8.121183
#
#                       pct_counts_in_top_50_genes  pct_counts_in_top_100_genes  \
# AAACCTGAGTCAATAG-1_2                   40.541295                    53.069196
# AAACCTGCATTAACCG-1_2                   35.881958                    46.948357
# AAACCTGTCAGCACAT-1_2                   47.198642                    61.139408
# AAACGGGGTCGCCATG-1_2                   46.542670                    61.684902
# AAACGGGGTTAAAGTG-1_2                   34.692850                    46.878147
# ...                                          ...                          ...
# TTTGGTTAGGCGACAT-1_2                   39.538043                    51.358696
# TTTGGTTGTCAGAGGT-1_2                   36.354420                    48.580697
# TTTGGTTTCACAGTAC-1_2                   29.383886                    38.636877
# TTTGTCACACATCCAA-1_2                   40.411718                    55.502771
# TTTGTCAGTTGTACAC-1_2                   42.390012                    54.875149
#
#                       pct_counts_in_top_200_genes  \
# AAACCTGAGTCAATAG-1_2                    63.616071
# AAACCTGCATTAACCG-1_2                    58.819584
# AAACCTGTCAGCACAT-1_2                    70.514997
# AAACGGGGTCGCCATG-1_2                    71.553611
# AAACGGGGTTAAAGTG-1_2                    58.131923
# ...                                           ...
# TTTGGTTAGGCGACAT-1_2                    61.467391
# TTTGGTTGTCAGAGGT-1_2                    60.442011
# TTTGGTTTCACAGTAC-1_2                    48.747461
# TTTGTCACACATCCAA-1_2                    65.558195
# TTTGTCAGTTGTACAC-1_2                    64.833532
#
#                       pct_counts_in_top_500_genes  total_counts_mt  \
# AAACCTGAGTCAATAG-1_2                    77.204241            316.0
# AAACCTGCATTAACCG-1_2                    75.050302            191.0
# AAACCTGTCAGCACAT-1_2                    81.550651            218.0
# AAACGGGGTCGCCATG-1_2                    82.538293            287.0
# AAACGGGGTTAAAGTG-1_2                    73.388721            410.0
# ...                                           ...              ...
# TTTGGTTAGGCGACAT-1_2                    75.054348            262.0
# TTTGGTTGTCAGAGGT-1_2                    74.939173            359.0
# TTTGGTTTCACAGTAC-1_2                    64.928910            380.0
# TTTGTCACACATCCAA-1_2                    76.769596            349.0
# TTTGTCAGTTGTACAC-1_2                    77.497027            195.0
#
#                       log1p_total_counts_mt  pct_counts_mt
# AAACCTGAGTCAATAG-1_2               5.758902       8.816964
# AAACCTGCATTAACCG-1_2               5.257495       6.405097
# AAACCTGTCAGCACAT-1_2               5.389072       4.112432
# AAACGGGGTCGCCATG-1_2               5.662960       6.280088
# AAACGGGGTTAAAGTG-1_2               6.018593      10.322256
# ...                                     ...            ...
# TTTGGTTAGGCGACAT-1_2               5.572154       7.119565
# TTTGGTTGTCAGAGGT-1_2               5.886104       7.278994
# TTTGGTTTCACAGTAC-1_2               5.942799       8.575942
# TTTGTCACACATCCAA-1_2               5.857933       5.526524
# TTTGTCAGTTGTACAC-1_2               5.278115       5.796671
#
# [1946 rows x 14 columns]

# %%
adata.obs[adata.obs['log1p_total_counts']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-9dd5076d4f15> in <cell line: 1>()
# ----> 1 adata.obs[adata.obs['log1p_total_counts']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index([ 5.998936561946683,  8.184513753033722,  6.591673732008658,\n        7.457609289715606,  8.000684784514748,  6.395261598115449,\n        7.985824666418917,   8.57583938684897,  6.577861357721047,\n        6.626717749249025,\n       ...\n        8.750841375375533,  6.612041034833092, 5.0369526024136295,\n        5.420534999272286,  7.486613313139955,  8.121183242078828,\n        6.452048954437226,  6.852242569051878, 6.8416154764775925,\n        5.438079308923196],\n      dtype='float64', length=6410)] are in the [columns]"

# %%
##################################################
# filter out cells by choosing QC thresholds
# e.g., based on the above plots, ok to be lenient we can revisit this after clustering

adata = adata[ adata.obs['log1p_total_counts']> 6.5 ]
adata = adata[ adata.obs['pct_counts_mt']< 15 ]

# %%
adata # notice that the number of cells decreased
# Out:
# View of AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %% [markdown]
# ### Doublet detection (scrublet)

# %% [markdown]
# - We expect very few doublets in this particular case. The majority of doublets were removed using genetic information / patient SNPs.

# %%
#############################################
# doublet detection with scrublet
sc.pp.scrublet(adata)

# %%
adata # notice the columns 'doublet_score' and 'predicted_doublet' were added in obs. Also .uns appeared.
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'scrublet'

# %%
# .value_counts(): count how many times a value appears in a column of a dataframe
adata.obs.value_counts('predicted_doublet')
# Out:
# predicted_doublet
# False    4451
# True        2
# Name: count, dtype: int64

# %%
##############################################
# [🔺] AnnData challenge: filter out detected doublets!
# Hint1: adata can be sliced as a DataFrame, i.e., adata[ some condition here ]
# Hint2: adata.obs has the predicted_doublet column which is False for the cells we want to keep

adata.obs['predicted_doublet'] == False
adata = adata['condition']

adata
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'condition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-a67b73869b44> in <cell line: 7>()
#       5
#       6 adata.obs['predicted_doublet'] == False
# ----> 7 adata = adata['condition']
#       8
#       9 adata
#
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py in __getitem__(self, index)
#    1019     def __getitem__(self, index: Index) -> AnnData:
#    1020         """Returns a sliced view of the object."""
# -> 1021         oidx, vidx = self._normalize_indices(index)
#    1022         return AnnData(self, oidx=oidx, vidx=vidx, asview=True)
#    1023
#
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py in _normalize_indices(self, index)
#    1000
#    1001     def _normalize_indices(self, index: Index | None) -> tuple[slice, slice]:
# -> 1002         return _normalize_indices(index, self.obs_names, self.var_names)
#    1003
#    1004     # TODO: this is not quite complete...
#
# /usr/local/lib/python3.10/dist-packages/anndata/_core/index.py in _normalize_indices(index, names0, names1)
#      36             index = index[0].values, index[1]
#      37     ax0, ax1 = unpack_index(index)
# ---> 38     ax0 = _normalize_index(ax0, names0)
#      39     ax1 = _normalize_index(ax1, names1)
#      40     return ax0, ax1
#
# /usr/local/lib/python3.10/dist-packages/anndata/_core/index.py in _normalize_index(indexer, index)
#      74         return indexer
#      75     elif isinstance(indexer, str):
# ---> 76         return index.get_loc(indexer)  # int
#      77     elif isinstance(indexer, (Sequence, np.ndarray, pd.Index, spmatrix, np.matrix)):
#      78         if hasattr(indexer, "shape") and (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'condition'

# %% [markdown]
# ## STEP 2: Normalization and log-transformation

# %%
##############################################
# Before normalization, we want to save the count data to a new layer
adata.layers["counts"] = adata.X.copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'scrublet'
#     layers: 'counts'

# %%
##############################################
# Normalizing to 10K total counts
sc.pp.normalize_total(adata,target_sum=10000) # CP10k normalization

# %% [markdown]
# - `target_sum = 10000` is kind of arbitrary but very widely used. If we don't specify the target_sum parameter, `sc.pp.normalize_total(adata)` by default will normalize to the median of the total counts.

# %%
# The only thing that changed is the X matrix (gene expression),
# which is now normalized to sum to 10K
adata.X.sum(1)
# Out:
# matrix([[10000.],
#         [10000.],
#         [10000.],
#         ...,
#         [10000.],
#         [10000.],
#         [10000.]])

# %%
##############################################
# Logarithmize the data
sc.pp.log1p(adata)

# %%
adata.X.sum(1) # the X matrix changed. Each entry is now log(1+x)
# Out:
# matrix([[2206.50442962],
#         [1146.63708348],
#         [1608.12643059],
#         ...,
#         [2139.56974705],
#         [1353.63176362],
#         [1412.3376114 ]])

# %%
######################################################
# [🔺] save the log1p normalized counts to a new layer! Let's call it 'log1p'
# We want to keep these around (useful for plotting and differential expression analysis)

adata.layers["log1p"] = adata.X.copy()

# %% [markdown]
# ## STEP 3: Highly variable genes (feature selection)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'scrublet', 'log1p', 'hvg'
#     layers: 'counts', 'log1p'

# %%
######################################################
sc.pp.highly_variable_genes(adata, n_top_genes = 2000,
                            flavor='seurat_v3',
                            layer='counts')

# %%
# This added information in the var dataframe
adata.var
# Out:
#                    gene_name     mt  n_cells_by_counts  mean_counts  \
# RP11-34P13.15  RP11-34P13.15  False                 44     0.006864
# RP11-34P13.13  RP11-34P13.13  False                 46     0.007332
# FO538757.1        FO538757.1  False                103     0.016381
# AP006222.2        AP006222.2  False                  5     0.000780
# RP4-669L17.10  RP4-669L17.10  False                  9     0.001404
# ...                      ...    ...                ...          ...
# AP001432.14      AP001432.14  False                  5     0.000780
# UMODL1-AS1        UMODL1-AS1  False                  5     0.000780
# AP001469.7        AP001469.7  False                  5     0.000780
# MT-TY                  MT-TY   True                  5     0.000780
# MT-TH                  MT-TH   True                  5     0.000780
#
#                log1p_mean_counts  pct_dropout_by_counts  total_counts  \
# RP11-34P13.15           0.006841              99.313573          44.0
# RP11-34P13.13           0.007306              99.282371          47.0
# FO538757.1              0.016248              98.393136         105.0
# AP006222.2              0.000780              99.921997           5.0
# RP4-669L17.10           0.001403              99.859594           9.0
# ...                          ...                    ...           ...
# AP001432.14             0.000780              99.921997           5.0
# UMODL1-AS1              0.000780              99.921997           5.0
# AP001469.7              0.000780              99.921997           5.0
# MT-TY                   0.000780              99.921997           5.0
# MT-TH                   0.000780              99.921997           5.0
#
#                log1p_total_counts  n_cells  highly_variable  \
# RP11-34P13.15            3.806662       44            False
# RP11-34P13.13            3.871201       46            False
# FO538757.1               4.663439      103            False
# AP006222.2               1.791759        5            False
# RP4-669L17.10            2.302585        9            False
# ...                           ...      ...              ...
# AP001432.14              1.791759        5            False
# UMODL1-AS1               1.791759        5            False
# AP001469.7               1.791759        5            False
# MT-TY                    1.791759        5            False
# MT-TH                    1.791759        5            False
#
#                highly_variable_rank     means  variances  variances_norm
# RP11-34P13.15                   NaN  0.008983   0.008904        0.869962
# RP11-34P13.13                   NaN  0.009207   0.009574        0.912331
# FO538757.1                      NaN  0.022008   0.022427        0.888107
# AP006222.2                      NaN  0.001123   0.001122        0.982316
# RP4-669L17.10                   NaN  0.001797   0.001794        0.952183
# ...                             ...       ...        ...             ...
# AP001432.14                     NaN  0.001123   0.001122        0.982316
# UMODL1-AS1                      NaN  0.001123   0.001122        0.982316
# AP001469.7                      NaN  0.000898   0.000898        0.994711
# MT-TY                           NaN  0.001123   0.001122        0.982316
# MT-TH                           NaN  0.000898   0.000898        0.994711
#
# [17473 rows x 14 columns]

# %%
# .sort_values(): sort a dataframe with respect to the values of a given column
# .head(10) prints the top 10
adata.var.sort_values('highly_variable_rank').head(10)
# Out:
#          gene_name     mt  n_cells_by_counts  mean_counts  log1p_mean_counts  \
# IGKV3-15  IGKV3-15  False                 53     0.209984           0.190607
# IGKV4-1    IGKV4-1  False                182     2.540562           1.264285
# TRBV7-2    TRBV7-2  False                121     0.172855           0.159441
# PTGDS        PTGDS  False                257     0.294072           0.257794
# FCER1A      FCER1A  False                118     0.122933           0.115944
# JCHAIN      JCHAIN  False                234     0.612793           0.477967
# LYPD2        LYPD2  False                173     0.147894           0.137929
# IGLV1-44  IGLV1-44  False                 60     0.074259           0.071631
# IGLV3-1    IGLV3-1  False                 35     0.069735           0.067411
# IGKC          IGKC  False                558     1.987207           1.094339
#
#           pct_dropout_by_counts  total_counts  log1p_total_counts  n_cells  \
# IGKV3-15              99.173167        1346.0            7.205635       53
# IGKV4-1               97.160686       16285.0            9.698061      182
# TRBV7-2               98.112324        1108.0            7.011214      121
# PTGDS                 95.990640        1885.0            7.542213      257
# FCER1A                98.159126         788.0            6.670766      118
# JCHAIN                96.349454        3928.0            8.276140      234
# LYPD2                 97.301092         948.0            6.855409      173
# IGLV1-44              99.063963         476.0            6.167516       60
# IGLV3-1               99.453978         447.0            6.104793       35
# IGKC                  91.294852       12738.0            9.452423      558
#
#           highly_variable  highly_variable_rank     means    variances  \
# IGKV3-15             True                   0.0  0.287447    23.036853
# IGKV4-1              True                   1.0  3.640467  5737.919449
# TRBV7-2              True                   2.0  0.240512     4.883066
# PTGDS                True                   3.0  0.379295    12.465941
# FCER1A               True                   4.0  0.174265     3.403587
# JCHAIN               True                   5.0  0.862565   307.563767
# LYPD2                True                   6.0  0.186616     2.991447
# IGLV1-44             True                   7.0  0.101280     3.716380
# IGLV3-1              True                   8.0  0.097013     2.992383
# IGKC                 True                   9.0  2.785987  3319.434197
#
#           variances_norm
# IGKV3-15       16.098598
# IGKV4-1        14.778441
# TRBV7-2        13.858238
# PTGDS          13.519210
# FCER1A         12.984669
# JCHAIN         12.334004
# LYPD2          11.757547
# IGLV1-44       11.057061
# IGLV3-1        11.034449
# IGKC           10.765065

# %% [markdown]
# ## STEP 4: Dimensionality reduction with PCA

# %%
adata # lets remind ourseleves about adata, the PCA will add a more information
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'scrublet', 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts', 'log1p'

# %%
#####################################################################
# Before PCA we typically scale features to unit variance (common step but not absolutely necessary)
# Note that this changes adata.X
sc.pp.scale(adata, zero_center=False) # we don't want to zero center.

# %%
#####################################################################
# PCA: by default this function uses only the highly variable genes
sc.tl.pca(adata, n_comps=50) # specify number of PCs (default is 50)

# %%
# notice that the .obsm appeared that holds representations of the cells (embeddings)
adata
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'scrublet', 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts', 'log1p'

# %%
# X_pca is a matrix of reduced dimensions (n_comps=50 in our case).
adata.obsm['X_pca'].shape
# Out:
# (4453, 50)

# %% [markdown]
# ### Visualize PCA

# %%
sc.pl.pca(adata,size=50)

# %%
sc.pl.pca(adata,color='patient_id',size=10)

# %%
sc.pl.pca(adata,color=['CST3','CD79A'],size=50,layer='log1p')

# %% [markdown]
# ## STEP 5: Nearest-neighbor graph, Clustering and UMAP projection

# %%
##############################################################
# construct a k nearest neighbors graph (knn)
# 1. choose which representation to use (default is 'X_pca')
# 2. choose n_neighbors (default is 15). Also can specify random_state for reproducibility.

sc.pp.neighbors(adata, use_rep='X_pca', n_neighbors=15, random_state=42)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'scrublet', 'log1p', 'hvg', 'pca', 'patient_id_colors', 'neighbors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts', 'log1p'
#     obsp: 'distances', 'connectivities'

# %%
##############################################################
# community detection algorithm that is used to cluster cells
# based on the neighbors graph we computed above.

sc.tl.leiden(adata, resolution=1, key_added='leiden') # default parameters

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'leiden'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'scrublet', 'log1p', 'hvg', 'pca', 'patient_id_colors', 'neighbors', 'leiden'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts', 'log1p'
#     obsp: 'distances', 'connectivities'

# %%
##############################################################
# run umap on the neighbors graph we computed above
sc.tl.umap(adata, min_dist=0.5, spread=1.0) # default values for the two main parameters

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4453 × 17473
#     obs: 'LIBRARY_ID', 'patient_id', 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'doublet_score', 'predicted_doublet', 'leiden'
#     var: 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'scrublet', 'log1p', 'hvg', 'pca', 'patient_id_colors', 'neighbors', 'leiden', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'log1p'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# ### Visualize UMAP

# %%
sc.pl.umap(adata,color=['CST3','CD79A'],size=50,layer='log1p')

# %%
sc.pl.umap(adata,color='leiden',size=50,legend_loc='on data')

# %%
##############################################################
# [🔺] Cluster the cells at a lower resolution, and visualize again
# Give a different name to the labels so that we don't overwrite the 'leiden' column in obs
# Hint: run the sc.tl.leiden and sc.pl.umap functions


sc.tl.leiden(adata, resolution=0.1, key_added='leiden_coarse')
sc.pl.umap(adata,color='leiden_coarse',size=50,legend_loc='on data')

# %%
# [🔹] Experiment with different neighbors, leiden and umap parameters

# lets work on a copy of the AnnData object for this
bdata = adata.copy() # anything we do with bdata won't affect adata

### pp.neighbors, tl.leiden, tl.umap and plot with pl.umap

# %% [markdown]
# ## Extra: Differential expression analysis

# %%
##############################################################
sc.tl.rank_genes_groups(adata,
                        groupby='leiden_coarse',
                        method='wilcoxon',
                        layer='log1p')

# %%
##############################################################
sc.pl.rank_genes_groups_dotplot(adata,
                                n_genes=6,
                                values_to_plot='logfoldchanges',
                                min_logfoldchange=3,
                                vmax=5,
                                vmin=-5,
                                cmap='bwr',
                                dot_max=0.7)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden_coarse). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %%
##############################################################
# [🔺] annotate the clusters!!

clusters_to_labels = {
    '0':'T cell',
    '1':'DC cells',
    '2':'NK cells',
    '3':'B cells'

}

# use the above dict to create a new column in obs with all cells labeled
# this is done by first mapping leiden_coarse column to the values of the dict
# and assigning the result to a new column in obs
adata.obs['???'] = adata.obs['leiden_coarse'].map(clusters_to_labels)


## umap plot with the new labels
sc.pl.umap(adata,color='???',size=50,legend_loc='on data',legend_fontoutline=2,legend_fontsize=10)

# %% [markdown]
# ## STEP 6: Save the processed dataset

# %%
adata.write_h5ad('blood_RNA_BMS225a_single_batch.h5ad') # this will be deleted when this session ends

# %%
### Too big to download so let's mount google drive from the Files tab and save it there
adata.write_h5ad('/content/drive/MyDrive/your_project_folder/blood_RNA_BMS225a_single_batch.h5ad')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-73-adf701a22f6c> in <cell line: 2>()
#       1 ### Too big to download so let's mount google drive from the Files tab and save it there
# ----> 2 adata.write_h5ad('/content/drive/MyDrive/your_project_folder/blood_RNA_BMS225a_single_batch.h5ad')
#
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py in write_h5ad(self, filename, compression, compression_opts, as_dense)
#    1861             filename = self.filename
#    1862
# -> 1863         write_h5ad(
#    1864             Path(filename),
#    1865             self,
#
# /usr/local/lib/python3.10/dist-packages/anndata/_io/h5ad.py in write_h5ad(filepath, adata, as_dense, dataset_kwargs, **kwargs)
#      72         adata.file.close()
#      73
# ---> 74     with h5py.File(filepath, mode) as f:
#      75         # TODO: Use spec writing system for this
#      76         # Currently can't use write_dispatched here because this function is also called to do an
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     560                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                                  fs_page_size=fs_page_size)
# --> 562                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563
#     564             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     240     elif mode == 'w':
# --> 241         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     242     elif mode == 'a':
#     243         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# FileNotFoundError: [Errno 2] Unable to synchronously create file (unable to open file: name = '/content/drive/MyDrive/your_project_folder/blood_RNA_BMS225a_single_batch.h5ad', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-74-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# # DONE

# %% [markdown]
# #  --> Compact version of the code

# %%
adata = sc.read_h5ad('blood_RNA_raw_counts_SCG12.h5ad') # load the AnnData object from the h5ad file
display(adata)

# QC and doublet detection
adata.var["mt"] = adata.var_names.str.startswith("MT-") # mitochondrial genes, "MT-" for human, "Mt-" for mouse
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True, log1p=True, percent_top = None) # calculate QC metrics
sc.pp.filter_genes(adata,min_cells=5) #filter genes
adata = adata[ adata.obs['log1p_total_counts']> 6.5 ] # filter cells based on counts
adata = adata[ adata.obs['pct_counts_mt']< 12.5 ] # filter cells based on mito percentage
sc.pp.scrublet(adata) # doublet detection with scrublet
adata = adata[ adata.obs['predicted_doublet'] == False ] # filter out detected doublets

# normalization and log-transformation
adata.layers["counts"] = adata.X.copy() # saving count data to a new layer, before we proceed with normalization
sc.pp.normalize_total(adata,target_sum=10000) # Normalizing to 10K total counts (CP10k)
sc.pp.log1p(adata) # Logarithmize the data
adata.layers['log1p'] = adata.X.copy() # save the log1p normalized counts to a new layer

# highly variable gene selection
sc.pp.highly_variable_genes(adata, n_top_genes = 2000, flavor='seurat_v3', layer='counts')

# dimensionality reduction (PCA)
sc.pp.scale(adata,zero_center=False) # scale each gene to unit variance (for pca only)
sc.tl.pca(adata, n_comps=50) # specify number of PCs (default is 50)

# knn graph, umap and leiden
sc.pp.neighbors(adata, use_rep='X_pca', n_neighbors=15, random_state=42)
sc.tl.umap(adata, min_dist=0.5, spread=1.0)
sc.tl.leiden(adata, resolution=0.1,key_added='leiden')

# plot
sc.pl.umap(adata, color=["leiden"],legend_loc='on data',legend_fontoutline=2)

display(adata)

# %% [markdown]
# # Reference based celltype annotation
#
# > A pre-processed **AnnData object** is needed to proceed with this section

# %%
# !pip install --quiet celltypist # https://www.celltypist.org/

# %% [markdown]
# <img src="https://github.com/Teichlab/celltypist/raw/main/docs/source/_static/img/logo_celltypist.png" alt="CellTypist Logo" width="300"/>
#
# Github: https://github.com/Teichlab/celltypist

# %%
import celltypist
celltypist.logger.set_level(2)

# %%
# Download Immune model:
celltypist.models.download_models(model='Immune_All_Low.pkl')

# %% [markdown]
# ### predict cell type labels

# %% [markdown]
# - before we start we will load the author's labels (to compare with our annotation later)

# %%
# adding the author labels (no need to follow this)
adata.obs = adata.obs.join(sc.read_h5ad('blood_RNA.h5ad').obs['MK final coarse_V2'].rename('cell_type'))

# %%
####################################################################
# celltypist needs an "overclustering" of the data as input to start labeling cells.
# Then it starts merging clusters with the same labels
sc.tl.leiden(adata, resolution=5, key_added='leiden_overclustering')

# %%
####################################################################
# celltypist also expects adata.X to be log1p of CP10K normalized counts
adata.X = adata.layers['log1p']

# %%
predictions = celltypist.annotate(adata,
                                  model = 'Immune_All_Low.pkl',
                                  majority_voting = True, # majority voting to assign labels to clusters
                                  over_clustering='leiden_overclustering')

# %%
####################################################################
# update our adata with the celltypist labels
adata = predictions.to_adata()

# %%
adata

# %% [markdown]
# #### visualize predicted labels

# %%
sc.pl.umap(adata, color=["majority_voting"])

# %%
sc.pl.umap(adata, color=["cell_type"],legend_fontoutline=3,palette='tab20')

# %%
sc.settings.set_figure_params(dpi=100,fontsize=12, facecolor="white",figsize=(8,6),color_map='viridis')

celltypist.dotplot(predictions,use_as_reference='cell_type',use_as_prediction = 'majority_voting')

# %% [markdown]
# Celltypist did a pretty good job overall! But missed the gamma delta Tcell cluster (07_gd T cells)

# %%
sc.settings.set_figure_params(dpi=60,fontsize=18, facecolor="white",figsize=(6,6),color_map='viridis')

# Plot gene expression
sc.pl.umap(
    adata,
    color=["TRDV2","TRGV9",'cell_type'], # Tgd markers
    size=80,
    layer = 'log1p' #### always specify this to be 100% sure which "counts" you are using
)

# %% [markdown]
# # Batch effect correction
#
#  - Same steps as above but with the **full dataset**. Steps that are different are annotated with ✅

# %%
### Load the full dataset (all sequencing libraries)
adata = sc.read_h5ad('blood_RNA_raw_counts.h5ad') # load the AnnData object from the h5ad file
display(adata)

# %% [markdown]
# #### Quality control (same)
#
# > Advanced QC: In some cases we may need to apply different thresholds for each experimental batch or sample

# %%
adata.var["mt"] = adata.var_names.str.startswith("MT-") # mitochondrial genes, "MT-" for human, "Mt-" for mouse
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True, log1p=True, percent_top = None) # calculate QC metrics
sc.pp.filter_genes(adata,min_cells=5) #filter genes
adata = adata[ adata.obs['log1p_total_counts']> 6.5 ] # filter cells based on counts
adata = adata[ adata.obs['pct_counts_mt']< 12.5 ] # filter cells based on mito percentage

# %% [markdown]
# #### Doublet detection

# %%
### ✅ we specify batch key here (impossible to have doublets across experimental batches)
sc.pp.scrublet(adata, batch_key="LIBRARY_ID") # doublet detection with scrublet
adata = adata[ adata.obs['predicted_doublet'] == False ] # filter out detected doublets

# %% [markdown]
# #### Normalization (same)

# %%
### Normalization and log-transformation (same)
adata.layers["counts"] = adata.X.copy() # saving count data to a new layer, before we proceed with normalization
sc.pp.normalize_total(adata,target_sum=10000) # Normalizing to 10K total counts (CP10k)
sc.pp.log1p(adata) # Logarithmize the data
adata.layers['log1p'] = adata.X.copy() # save the log1p normalized counts to a new layer

# %% [markdown]
# #### HVG selection

# %%
### ✅ we specify batch key here too in order to take into account the (unwanted) variability across batches
sc.pp.highly_variable_genes(adata, n_top_genes = 2000, flavor='seurat_v3', layer='counts',batch_key='LIBRARY_ID')

# %% [markdown]
# #### PCA (same)

# %%
### dimensionality reduction (PCA) (same)
sc.pp.scale(adata,zero_center=False) # scale each gene to unit variance (for pca only)
sc.tl.pca(adata, n_comps=50) # specify number of PCs (default is 50)

# %% [markdown]
# #### Batch effect correction with Harmony

# %%
# ✅ This method uses the result of pca, to align the pcs across batches.
sc.external.pp.harmony_integrate(adata,key='LIBRARY_ID')

# %%
adata # notice that 'X_pca_harmony' was added in obsm

# %% [markdown]
# #### Clustering

# %%
### ✅ knn graph, umap and leiden
### We just use the corrected 'X_pca_harmony' instead of 'X_pca' for the neighbors graph!
sc.pp.neighbors(adata, use_rep='X_pca_harmony', n_neighbors=15, random_state=42)

# %%
### Everything else is the same
sc.tl.umap(adata, min_dist=0.5, spread=1.0)
sc.tl.leiden(adata, resolution=1,key_added='leiden')

### plot
sc.pl.umap(adata, color=["leiden"],legend_loc='on data',legend_fontoutline=2)
